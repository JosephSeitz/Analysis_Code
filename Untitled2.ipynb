# %%
import scipy as sc
from scipy import signal
import os   #used for directory work
import matplotlib.pyplot as plt #used for creating plots
import pandas as pd
import numpy as np
import matplotlib.patches as mpatches #used for plot legends
# %matplotlib inline

burn_d = {'01': [21000 ,22289], '02': [14000, 14972], '03': [20000, 20296], '04': [30000, 34979], '05': [15000, 15974], \
          '06': [6000, 6544], '07': [25000, 27822], '08': [18000, 19810], '09': [20000, 25047], '11': [30000,30681],  \
          '12': [60000, 62937], '13': [50000, 55131], '18': [185000, 192322], '19': [45000, 48831], '20': [24000, 25860],\
          '21': [25000, 27822], '22': [27000, 29484], '23': [45000, 48846], '24': [20000, 23015], '25': [25000, 26797], \
          '26': [25000, 26909], '27': [35000, 36916], '28': [27000, 28673], '29': [25000, 28166], '30': [12000, 13954], \
          '31': [30000, 31046], '32': [25000, 26294], '33': [20000, 23293], '34': [40000,43702]}

# %%
def text_finder(path):
    txt_files=[]
    all_files = os.listdir(path) #tells what directory the files are in
    for i in all_files: #reading only the .txt files 
        if i[-4:] == ".txt":
            txt_files.append(i)
    txt_files.sort() #alphabetizes them
    
    return txt_files

def file_to_df(path):
    df= pd.read_csv(path,na_values = ['NAN', "00nan", "NaN"], sep=" ")
    #df.fillna(value=np.nan, inplace=True)
    
    return df
                
def fire_start(df,n, sig = 5):    
    ### Finding the start of fire
    x_fire, fire_sig = 9e10, np.nanmean(df["T"][:n])+sig*np.std(df["T"][:n]) 
    start = n-9000
    if n-9000< 0:
        start = 0
        
    for i in range(n, len(df["T"])):
        if df["T"][i] > fire_sig:
            x_fire = i
            break
    
    return x_fire

def speed_calculation(df):
    horizontal_speed = np.sqrt(df["V"]**2 + df["U"]**2)**2
    return horizontal_speed

def kinectic_tke(df,x_fire):
    u_pre_lst, u_brn_lst, u_pst_lst = fire_period_split(list(df["U"]), x_fire)
    v_pre_lst, v_brn_lst, v_pst_lst = fire_period_split(list(df["V"]), x_fire)
    w_pre_lst, w_brn_lst, w_pst_lst = fire_period_split(list(df["W"]), x_fire)
    
    pre_tke_lst, brn_tke_lst, pst_tke_lst = np.full(len(u_pre_lst),np.nan), \
                    np.full(len(u_brn_lst),np.nan), np.full(len(u_pst_lst),np.nan)
    
    for i in range(len(u_pre_lst)):
        pre_tke_lst[i] = (u_pre_lst[i]**2 + v_pre_lst[i]**2 + w_pre_lst[i]**2)/2
        
    for i in range(len(u_brn_lst)):
        brn_tke_lst[i] = (u_brn_lst[i]**2 + v_brn_lst[i]**2 + w_brn_lst[i]**2)/2
    
    for i in range(len(u_pst_lst)):
        pst_tke_lst[i] = (u_pst_lst[i]**2 + v_pst_lst[i]**2 + w_pst_lst[i]**2)/2
    
    return pre_tke_lst, brn_tke_lst, pst_tke_lst
        
def fire_period_split(var_lst, x_fire, period_t = 9000):
    
    t_start, f_end, t_end  =x_fire-period_t, x_fire+period_t, (len(var_lst)-1)
    if t_start < 0:
        t_start = 0
    
    pre_lst = list(var_lst[int(t_start) : int(x_fire)])
    brn_lst = list(var_lst[int(x_fire) : int(x_fire+period_t)])
    pst_lst = list(var_lst[int(x_fire+period_t) : int(x_fire+(period_t*2))])
    var_mean = np.nanmean(pre_lst)
        
    pre_lst -= var_mean
    brn_lst -= var_mean
    pst_lst -= var_mean
    
    return pre_lst, brn_lst, pst_lst

def lin_rb(freq, power, n_bins, new_n_bins):
    """
    Linear redistribution
    """
    lin_rb_psd, f_bin_edges, something = sc.stats.binned_statistic(freq, power,\
                                            statistic='mean',bins=new_n_bins)

    new_df = np.median(np.diff(f_bin_edges))
    new_freq = f_bin_edges[0:-1] + 0.5 * new_df  # so that the freq is mid-bin

    return new_freq, new_df, lin_rb_psd

def fast_fourier_transform(var_lst,binn = 100, T= 0.1, redist = True):
    from scipy.fft import fft, ifft
    
    N = len(var_lst)
    if N < binn:
        return [np.nan],[np.nan]
    
    df = pd.DataFrame()
    df["var"] = var_lst
    df = df.interpolate(method='linear', axis=0)
    df.fillna(value=0, inplace=True)
    data = np.array(df["var"])
    
    # Number of sample points
    N = len(data)
    # sample spacing
    x = np.linspace(0.0, N*T, N)
    yf = fft(np.array(data))
    xf = np.linspace(0.0, 1.0/(2.0*T), N//2)
    yfft =  np.abs(yf[0:N//2])
    power = np.multiply(yfft, np.conj(yfft))
    if redist == False:
        return xf, power
    
    if redist == True:
        new_x, df_stat, powery = lin_rb(xf,power,N,binn)
    
    return  new_x, powery

def guide_lines(N = 10):
    x = np.logspace(-.5,.5,50)
    e_5_3, e_7_3, e_2_3= [], [], []
    for i in x:
        #e_5_3.append((i*N**(-7))**((-5/3)))
        #e_7_3.append((i*N**(-7))**((-7/3)))
        e_2_3.append((i*N**(-7))**((-2/3)))
    return x, e_2_3

# %%
path = "/Users/joeyp/Desktop/10X10_Truss_SERDP_Burns/JS_Cleaned_Data/Full-Timestamp/Burn-" #w10
path_end = "/sonics/"
sc_name_lst= ["A1","A2", "A3", "A4", "B1", "B2", "B3", "B4", \
                 "C1", "C2", "C3", "C4", "D1", "D2", "D3", "D4"]
df_index_lst = []

for brn in list(burn_d.keys()):
    for snc in sc_name_lst:
        df_index_lst.append(str("B"+brn+snc))
print(df_index_lst)
# Out:
# ['B01A1', 'B01A2', 'B01A3', 'B01A4', 'B01B1', 'B01B2', 'B01B3', 'B01B4', 'B01C1', 'B01C2', 'B01C3', 'B01C4', 'B01D1', 'B01D2', 'B01D3', 'B01D4', 'B02A1', 'B02A2', 'B02A3', 'B02A4', 'B02B1', 'B02B2', 'B02B3', 'B02B4', 'B02C1', 'B02C2', 'B02C3', 'B02C4', 'B02D1', 'B02D2', 'B02D3', 'B02D4', 'B03A1', 'B03A2', 'B03A3', 'B03A4', 'B03B1', 'B03B2', 'B03B3', 'B03B4', 'B03C1', 'B03C2', 'B03C3', 'B03C4', 'B03D1', 'B03D2', 'B03D3', 'B03D4', 'B04A1', 'B04A2', 'B04A3', 'B04A4', 'B04B1', 'B04B2', 'B04B3', 'B04B4', 'B04C1', 'B04C2', 'B04C3', 'B04C4', 'B04D1', 'B04D2', 'B04D3', 'B04D4', 'B05A1', 'B05A2', 'B05A3', 'B05A4', 'B05B1', 'B05B2', 'B05B3', 'B05B4', 'B05C1', 'B05C2', 'B05C3', 'B05C4', 'B05D1', 'B05D2', 'B05D3', 'B05D4', 'B06A1', 'B06A2', 'B06A3', 'B06A4', 'B06B1', 'B06B2', 'B06B3', 'B06B4', 'B06C1', 'B06C2', 'B06C3', 'B06C4', 'B06D1', 'B06D2', 'B06D3', 'B06D4', 'B07A1', 'B07A2', 'B07A3', 'B07A4', 'B07B1', 'B07B2', 'B07B3', 'B07B4', 'B07C1', 'B07C2', 'B07C3', 'B07C4', 'B07D1', 'B07D2', 'B07D3', 'B07D4', 'B08A1', 'B08A2', 'B08A3', 'B08A4', 'B08B1', 'B08B2', 'B08B3', 'B08B4', 'B08C1', 'B08C2', 'B08C3', 'B08C4', 'B08D1', 'B08D2', 'B08D3', 'B08D4', 'B09A1', 'B09A2', 'B09A3', 'B09A4', 'B09B1', 'B09B2', 'B09B3', 'B09B4', 'B09C1', 'B09C2', 'B09C3', 'B09C4', 'B09D1', 'B09D2', 'B09D3', 'B09D4', 'B11A1', 'B11A2', 'B11A3', 'B11A4', 'B11B1', 'B11B2', 'B11B3', 'B11B4', 'B11C1', 'B11C2', 'B11C3', 'B11C4', 'B11D1', 'B11D2', 'B11D3', 'B11D4', 'B12A1', 'B12A2', 'B12A3', 'B12A4', 'B12B1', 'B12B2', 'B12B3', 'B12B4', 'B12C1', 'B12C2', 'B12C3', 'B12C4', 'B12D1', 'B12D2', 'B12D3', 'B12D4', 'B13A1', 'B13A2', 'B13A3', 'B13A4', 'B13B1', 'B13B2', 'B13B3', 'B13B4', 'B13C1', 'B13C2', 'B13C3', 'B13C4', 'B13D1', 'B13D2', 'B13D3', 'B13D4', 'B18A1', 'B18A2', 'B18A3', 'B18A4', 'B18B1', 'B18B2', 'B18B3', 'B18B4', 'B18C1', 'B18C2', 'B18C3', 'B18C4', 'B18D1', 'B18D2', 'B18D3', 'B18D4', 'B19A1', 'B19A2', 'B19A3', 'B19A4', 'B19B1', 'B19B2', 'B19B3', 'B19B4', 'B19C1', 'B19C2', 'B19C3', 'B19C4', 'B19D1', 'B19D2', 'B19D3', 'B19D4', 'B20A1', 'B20A2', 'B20A3', 'B20A4', 'B20B1', 'B20B2', 'B20B3', 'B20B4', 'B20C1', 'B20C2', 'B20C3', 'B20C4', 'B20D1', 'B20D2', 'B20D3', 'B20D4', 'B21A1', 'B21A2', 'B21A3', 'B21A4', 'B21B1', 'B21B2', 'B21B3', 'B21B4', 'B21C1', 'B21C2', 'B21C3', 'B21C4', 'B21D1', 'B21D2', 'B21D3', 'B21D4', 'B22A1', 'B22A2', 'B22A3', 'B22A4', 'B22B1', 'B22B2', 'B22B3', 'B22B4', 'B22C1', 'B22C2', 'B22C3', 'B22C4', 'B22D1', 'B22D2', 'B22D3', 'B22D4', 'B23A1', 'B23A2', 'B23A3', 'B23A4', 'B23B1', 'B23B2', 'B23B3', 'B23B4', 'B23C1', 'B23C2', 'B23C3', 'B23C4', 'B23D1', 'B23D2', 'B23D3', 'B23D4', 'B24A1', 'B24A2', 'B24A3', 'B24A4', 'B24B1', 'B24B2', 'B24B3', 'B24B4', 'B24C1', 'B24C2', 'B24C3', 'B24C4', 'B24D1', 'B24D2', 'B24D3', 'B24D4', 'B25A1', 'B25A2', 'B25A3', 'B25A4', 'B25B1', 'B25B2', 'B25B3', 'B25B4', 'B25C1', 'B25C2', 'B25C3', 'B25C4', 'B25D1', 'B25D2', 'B25D3', 'B25D4', 'B26A1', 'B26A2', 'B26A3', 'B26A4', 'B26B1', 'B26B2', 'B26B3', 'B26B4', 'B26C1', 'B26C2', 'B26C3', 'B26C4', 'B26D1', 'B26D2', 'B26D3', 'B26D4', 'B27A1', 'B27A2', 'B27A3', 'B27A4', 'B27B1', 'B27B2', 'B27B3', 'B27B4', 'B27C1', 'B27C2', 'B27C3', 'B27C4', 'B27D1', 'B27D2', 'B27D3', 'B27D4', 'B28A1', 'B28A2', 'B28A3', 'B28A4', 'B28B1', 'B28B2', 'B28B3', 'B28B4', 'B28C1', 'B28C2', 'B28C3', 'B28C4', 'B28D1', 'B28D2', 'B28D3', 'B28D4', 'B29A1', 'B29A2', 'B29A3', 'B29A4', 'B29B1', 'B29B2', 'B29B3', 'B29B4', 'B29C1', 'B29C2', 'B29C3', 'B29C4', 'B29D1', 'B29D2', 'B29D3', 'B29D4', 'B30A1', 'B30A2', 'B30A3', 'B30A4', 'B30B1', 'B30B2', 'B30B3', 'B30B4', 'B30C1', 'B30C2', 'B30C3', 'B30C4', 'B30D1', 'B30D2', 'B30D3', 'B30D4', 'B31A1', 'B31A2', 'B31A3', 'B31A4', 'B31B1', 'B31B2', 'B31B3', 'B31B4', 'B31C1', 'B31C2', 'B31C3', 'B31C4', 'B31D1', 'B31D2', 'B31D3', 'B31D4', 'B32A1', 'B32A2', 'B32A3', 'B32A4', 'B32B1', 'B32B2', 'B32B3', 'B32B4', 'B32C1', 'B32C2', 'B32C3', 'B32C4', 'B32D1', 'B32D2', 'B32D3', 'B32D4', 'B33A1', 'B33A2', 'B33A3', 'B33A4', 'B33B1', 'B33B2', 'B33B3', 'B33B4', 'B33C1', 'B33C2', 'B33C3', 'B33C4', 'B3 ...

# %%
variable = "T"
sigma_fire = False
sig = 5
def master_spectra(variable, sigma_fire, sig):
    path = "/Users/joeyp/Desktop/10X10_Truss_SERDP_Burns/JS_Cleaned_Data/Full-Timestamp/Burn-" #w10
    path_end = "/sonics/"
    sc_name_lst= ["A1","A2", "A3", "A4", "B1", "B2", "B3", "B4", \
                     "C1", "C2", "C3", "C4", "D1", "D2", "D3", "D4"]
    df_index_lst = []

    for brn in list(burn_d.keys()):
        for snc in sc_name_lst:
            df_index_lst.append(str("B"+brn+snc))

    df_pre_x_master, df_pre_y_master = pd.DataFrame(), pd.DataFrame()
    df_brn_x_master, df_brn_y_master = pd.DataFrame(), pd.DataFrame()
    df_pst_x_master, df_pst_y_master = pd.DataFrame(), pd.DataFrame()

    pre_snc_cnt, brn_snc_cnt, pst_snc_cnt = 0, 0, 0
    snc_cnt = 0
    for brn in range(len(list(burn_d.keys()))):
        burn = list(burn_d.keys())[brn]
        p = path+burn+ path_end
        files = text_finder(p)
        for i in range(16):

            df = file_to_df(p+files[i])

            if sigma_fire == True:
                
                if variable == "TKE":
                    pre_lst, brn_lst, pst_lst = kinectic_tke(list(df[variable]), burn_d[burn][1])
                if variable =="W" or variable == "U" or variable == "V" or variable == "T":
                    pre_lst, brn_lst, pst_lst = fire_period_split(list(df[variable]), burn_d[burn][1])
                if variable == "S":
                    pre_lst, brn_lst, pst_lst = fire_period_split(speed_calculation(df), burn_d[burn][1])

            if sigma_fire == False:
                x_fire = fire_start(df, burn_d[burn][0], sig = sig)
                if variable == "TKE":
                    pre_lst, brn_lst, pst_lst = kinectic_tke(list(df[variable]), burn_d[burn][1])
                if variable =="W" or variable == "U" or variable == "V" or variable == "T":
                    pre_lst, brn_lst, pst_lst = fire_period_split(list(df[variable]), x_fire)
                if variable == "S":
                    pre_lst, brn_lst, pst_lst = fire_period_split(speed_calculation(df), x_fire)

            pre_x, pre_y = fast_fourier_transform(np.multiply(pre_lst,pre_lst),redist=False)#binn)
            brn_x, brn_y = fast_fourier_transform(np.multiply(brn_lst,brn_lst),redist=False)#binn)
            pst_x, pst_y = fast_fourier_transform(np.multiply(pst_lst,pst_lst),redist=False)#binn)

            if len(pre_x) == 4500 and len(pre_y) ==4500:
                df_pre_x_master[df_index_lst[snc_cnt]+"_x"] = pre_x
                df_pre_y_master[df_index_lst[snc_cnt]+"_y"] = pre_y
                pre_snc_cnt+= 1
            if len(brn_x) == 4500 and len(brn_y) ==4500:
                df_brn_x_master[df_index_lst[snc_cnt]+"_x"] = brn_x
                df_brn_y_master[df_index_lst[snc_cnt]+"_y"] = brn_y
                brn_snc_cnt += 1
            if len(pst_x) == 4500 and len(pst_y) ==4500:
                df_pst_x_master[df_index_lst[snc_cnt]+"_x"] = pst_x
                df_pst_y_master[df_index_lst[snc_cnt]+"_y"] = pst_y
                pst_snc_cnt += 1

            snc_cnt+= 1
    print("PRE Sonics:",pre_snc_cnt, "BRN Sonics:", brn_snc_cnt,\
         "PST Sonics:", pst_snc_cnt)
            
    df_master = [df_pre_x_master, df_pre_y_master, df_brn_x_master, df_brn_y_master, \
                    df_pst_x_master, df_pst_y_master]
    return df_master

# %%
df_master_1 = master_spectra("T", True, 5)
x1, y1 = df_master_1[0].mean(axis = 1), df_master_1[1].mean(axis = 1)
x2, y2 = df_master_1[2].mean(axis = 1), df_master_1[3].mean(axis = 1)
x3, y3 = df_master_1[4].mean(axis = 1), df_master_1[5].mean(axis = 1)

new_x1, df_stat_1, new_y1 = lin_rb(x1,y1,9000,100)
new_x2, df_stat_2, new_y2 = lin_rb(x2,y2,9000,100)
new_x3, df_stat_3, new_y3 = lin_rb(x3,y3,9000,100)



plt.loglog(new_x1, new_y1*new_x1, c = 'b')
plt.loglog(new_x2, new_y2*new_x2, c = "r")
plt.loglog(new_x3, new_y3*new_x3, c = "g")
# Out:
# C:\Users\joeyp\anaconda3\lib\site-packages\ipykernel_launcher.py:63: RuntimeWarning: Mean of empty slice
# PRE Sonics: 448 BRN Sonics: 416 PST Sonics: 240

# %%
df_master_2 = master_spectra("T", False, 5)
x12, y12 = df_master_2[0].mean(axis = 1), df_master_2[1].mean(axis = 1)
x22, y22 = df_master_2[2].mean(axis = 1), df_master_2[3].mean(axis = 1)
x32, y32 = df_master_2[4].mean(axis = 1), df_master_2[5].mean(axis = 1)

new_x12, df_stat_12, new_y12 = lin_rb(x12,y12,9000,100)
new_x22, df_stat_22, new_y22 = lin_rb(x22,y22,9000,100)
new_x32, df_stat_32, new_y32 = lin_rb(x32,y32,9000,100)
# Out:
# C:\Users\joeyp\anaconda3\lib\site-packages\ipykernel_launcher.py:19: RuntimeWarning: Mean of empty slice
# C:\Users\joeyp\anaconda3\lib\site-packages\ipykernel_launcher.py:63: RuntimeWarning: Mean of empty slice
# PRE Sonics: 414 BRN Sonics: 361 PST Sonics: 215

# %%
guid_x, guid_y = guide_lines()
fig, axs = plt.subplots(nrows=1,ncols=3,figsize=(16,4))
ax1 = axs[0]
ax1.loglog(new_x1, new_y1*new_x1, c = 'b')
ax1.loglog(new_x12, new_y12*new_x12, c = 'b', linestyle = "--")
guid_x, guid_y = guide_lines(7)
ax1.loglog(guid_x,guid_y,c = "purple")
#ax3.set_ylim(10**2,10**6)

ax2 = axs[1]
ax2.loglog(new_x2, new_y2*new_x2, c = "r")
ax2.loglog(new_x22, new_y22*new_x22, c = "r", linestyle = "--")
guid_x, guid_y = guide_lines(80)
ax2.loglog(guid_x,guid_y,c = "purple")
#ax2.set_ylim(10**6,10**10)
ax3 = axs[2]
ax3.loglog(new_x3, new_y3*new_x3, c = "g")
ax3.loglog(new_x32, new_y32*new_x32, c = "g", linestyle = "--")
guid_x, guid_y = guide_lines(40)
ax3.loglog(guid_x,guid_y,c = "purple")
#ax3.set_ylim(10**6,10**10)
fig.subplots_adjust(hspace=0.1, wspace=0.1)

# %%
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True])
